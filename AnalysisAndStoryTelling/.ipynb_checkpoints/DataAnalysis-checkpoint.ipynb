# %%
import os
import pickle

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import datetime 

# Setup Seaborn
sns.set(rc={'figure.figsize':(20,8)})
sns.set_style("whitegrid", {'axes.grid' : True})

# %%
with open('../Data/Crisis_data_cleaned.txt', 'rb') as f:
    results = pickle.load(f)

# %%
df = pd.DataFrame.from_records(results)
#df.info()

# %%
sns.set(font_scale=1.5)
ax = sns.countplot(df.beat, palette="bright")
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x(), height+100,'%.0f'%(height), rotation=90)
plt.show()

# %%
sns.set(font_scale=1.25)
x_colnames = ['sector','precinct']

f, ax = plt.subplots(len(x_colnames), 1, figsize=(10,10), sharex=False, sharey=False)
for i in range(len(x_colnames)):
    axes = sns.countplot(x=x_colnames[i], data=df, ax=ax[i], palette="bright")
    ax[i].set_xticklabels(axes.get_xticklabels() ,rotation=90)
    ax[i].set_title(str(x_colnames[i]) , fontsize=16)
    for p in axes.patches:
        height = p.get_height()
        axes.text(p.get_x(), height+100, '%.0f'%(height))
plt.tight_layout()

# %%
precinct_sector[['precinct','sector','count']] = df[['precinct','sector']].groupby(['precinct','sector']).size().reset_index()
precinct_sector
# Out:
#      precinct   sector     0  count
# 0        EAST  CHARLIE  1877   1877
# 1        EAST   EDWARD  3901   3901
# 2        EAST   GEORGE  2543   2543
# 3       NORTH      BOY  2479   2479
# 4       NORTH     JOHN  1874   1874
# 5       NORTH  LINCOLN  2339   2339
# 6       NORTH     NORA  2993   2993
# 7       NORTH    UNION  2379   2379
# 8       SOUTH    OCEAN  1255   1255
# 9       SOUTH   ROBERT  2153   2153
# 10      SOUTH      SAM  1702   1702
# 11  SOUTHWEST    FRANK  1641   1641
# 12  SOUTHWEST  WILLIAM  1941   1941
# 13       WEST    DAVID  2943   2943
# 14       WEST     KING  4061   4061
# 15       WEST     MARY  2676   2676
# 16       WEST    QUEEN  1957   1957

# %%
ax = precinct_sector.pivot("precinct", "sector", "count").plot(kind='bar', stacked=False, figsize=(20,20))
plt.legend(loc='best')

for p in ax.patches:
    height = p.get_height()
    if (height > 100):
        ax.text(p.get_x(), height, '%.0f'%(height), rotation=90)
plt.show()

# %%
sns.set(font_scale=1.25)
plt.figure(figsize=(30,15))
ax = sns.countplot(df.officer_squad_desc, palette="bright")
plt.xticks(rotation=90)
for p in ax.patches:
    height = p.get_height()
    if (height > 100):
        ax.text(p.get_x(), height+150, '%.0f'%(height), rotation=90)
plt.show()

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,8))
ax = sns.countplot(df.officer_squad_desc, order=df.officer_squad_desc.value_counts().iloc[:50].index, palette="bright")
plt.xticks(rotation=90)
for p in ax.patches:
    height = p.get_height()
    if (height > 100):
        ax.text(p.get_x(), height+300, '%.0f'%(height), rotation=90)
plt.show()

# %%
sns.set(font_scale=1.5)
ax = sns.countplot(df.officer_precinct_desc, palette="bright")
plt.xticks(rotation=90)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x(), height+200, '%.0f'%(height), rotation=0)
plt.show()

# %%
sns.set(font_scale=1.25)
plt.figure(figsize=(10,5))
ax = sns.countplot(df.officer_bureau_desc, palette="bright")
plt.xticks(rotation=90)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+0.25, height, '%.0f'%(height))
plt.show()

# %%
sns.set(font_scale=2.0)

x_colnames = ['officer_years_of_experience','officer_year_of_birth']

f, ax = plt.subplots(len(x_colnames), 1, figsize=(25,10), sharex=False, sharey=False)
for i in range(len(x_colnames)):
    axes = sns.countplot(x=x_colnames[i], data=df, ax=ax[i], palette="bright")
    ax[i].set_xticklabels(axes.get_xticklabels() ,rotation=45)
    ax[i].set_title(str(x_colnames[i]) , fontsize=16)
    for p in axes.patches:
        height = p.get_height()
        extraheight = 800 if x_colnames[i] != 'officer_year_of_birth' else 300
        axes.text(p.get_x()+0.15, height+extraheight, '%.0f'%(height), rotation=90)
plt.tight_layout()

# %%
sns.set(font_scale=1.25)
plt.figure(figsize=(10,5))
ax = sns.countplot(df.officer_race,palette="bright")
plt.xticks(rotation=45)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+0.25, height+50, '%.0f'%(height))
plt.show()

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,8))
ax = sns.countplot(df.initial_call_type, order=df.initial_call_type.value_counts().iloc[:50].index, palette="bright")
plt.xticks(rotation=90)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x(), height+500, '%.0f'%(height), rotation=90)
plt.show()

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,8))
ax = sns.countplot(df.final_call_type, order=df.final_call_type.value_counts().iloc[:50].index, palette="bright")
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x(), height+2500, '%.0f'%(height), rotation=90)
plt.xticks(rotation=90)
plt.show()

# %%
sns.set(font_scale=1.25)
plt.figure(figsize=(10,5))
ax = sns.countplot(df.call_type, palette="bright")
plt.xticks(rotation=90)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+0.15, height+ 3, '%.0f'%(height))
plt.show()

# %%
sns.set(font_scale=2.0)
x_colnames = ['officer_years_of_experience','officer_year_of_birth','officer_race']

f, ax = plt.subplots(len(x_colnames), 1, figsize=(20,30), sharex=False, sharey=False)
for i in range(len(x_colnames)):
    axes = sns.countplot(x=x_colnames[i], data=df, ax=ax[i], hue='officer_gender')
    axes.legend(('Male','Female'))
    ax[i].set_xticklabels(axes.get_xticklabels() ,rotation=90)
    ax[i].set_title(str(x_colnames[i]) +" v officer_gender", fontsize=24)
    rotation = 90 if x_colnames[i] != 'officer_race' else 0
    for p in axes.patches:
        height = p.get_height()
        if (height > 100):
            extraheight = 500 if x_colnames[i] != 'officer_year_of_birth' else 300
            axes.text(p.get_x(), height+extraheight, '%.0f'%(height), rotation=rotation)
plt.tight_layout()

# %%
sns.set(font_scale=2.0)
x_colnames = ['officer_years_of_experience','officer_year_of_birth', 'officer_race']

f, ax = plt.subplots(len(x_colnames), 1, figsize=(20,40), sharex=False, sharey=False)
for i in range(len(x_colnames)):
    axes = sns.countplot(x=x_colnames[i], data=df, ax=ax[i], hue='use_of_force_indicator')
    axes.legend(('Male','Female'))
    ax[i].set_xticklabels(axes.get_xticklabels() ,rotation=90)
    ax[i].set_title(str(x_colnames[i]) +" v use_of_force_indicator", fontsize=24)
    rotation = 90 if x_colnames[i] != 'use_of_force_indicator' else 0
    for p in axes.patches:
        height = p.get_height()
        if (height > 0):
            extraheight = 300 if x_colnames[i] != 'officer_year_of_birth' else 100
            axes.text(p.get_x(), height+extraheight, '%.0f'%(height), rotation=rotation)
plt.tight_layout()

# %% [markdown]
# # Time Analysis.
